# %%
#from google.colab import drive
#drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#!cp gdrive/My\ Drive/N7/3A/Molecules/net_dinguerize.py gdrive/My\ Drive/N7/3A/Molecules/train_preprocess_coulomb.pkl gdrive/My\ Drive/N7/3A/Molecules/truetest_preprocess_coulomb.pkl .

# %%
#!python gdrive/My\ Drive/N7/3A/Molecules/train_net_dinguerize.py --epochs 2700 --batch_size 16 --lr 0.0001
# !python train_net_dinguerize.py --epochs 2700 --batch_size 16 --lr 0.0001
# Out:
# Number of parameters : 166011
#   0% 0/334 [00:00<?, ?it/s]gdrive/My Drive/N7/3A/Molecules/train_net_dinguerize.py:51: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:210.)
#   return_array = [self.transform(torch.tensor([self.x_pos[idx].reshape(23,23)],dtype=torch.float32))]
# epoch :   0 | training loss: 1868.9204683360940180: 100% 334/334 [00:01<00:00, 179.24it/s]
# epoch :   1 | training loss: 129.4901333654711948: 100% 334/334 [00:01<00:00, 189.84it/s]
# epoch :   2 | training loss: 127.5920880597508642: 100% 334/334 [00:01<00:00, 189.85it/s]
# epoch :   3 | training loss: 124.1123009184877333: 100% 334/334 [00:01<00:00, 184.39it/s]
# epoch :   4 | training loss: 119.2687969321976169: 100% 334/334 [00:01<00:00, 189.07it/s]
# ...
